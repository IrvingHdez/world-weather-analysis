# %% [markdown]
# ## Deliverable 1: Retrieve Weather Data

# %%
# Import dependencies
from citipy import citipy
import pandas as pd
import numpy as np
import json 
import requests
import timeit

from datetime import datetime
from config import weather_api_key

# %%
# Step 3: Create a new set of 2,000 random latitudes and longitudes.
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Unpack lat_lngs zip object into a list. This way, we only need to create a set of random latitudes and longitudes once. 
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Step 4: Get the nearest city using the citipy module
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Step 5: Perform an API call with the OpenWeatherMap
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# %%
# Step 6: Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print Getting Data from API.
print("Getting Data from API     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather['weather'][0]['description']
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-------------------------------")
print("Wheather Data from API recorded")
print("-------------------------------")
# Out:
# Getting Data from API
# -----------------------------
# Processing Record 1 of Set 1 | salalah
# Processing Record 2 of Set 1 | staritsa
# Processing Record 3 of Set 1 | pevek
# Processing Record 4 of Set 1 | colon
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | rocha
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | cidreira
# Processing Record 12 of Set 1 | irbil
# Processing Record 13 of Set 1 | isangel
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | kununurra
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | verkhnyaya inta
# Processing Record 18 of Set 1 | ponta do sol
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | mehamn
# Processing Record 21 of Set 1 | ketchikan
# Processing Record 22 of Set 1 | lorengau
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | port elizabeth
# Processing Record 26 of Set 1 | kruisfontein
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | lloydminster
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | alofi
# Processing Record 32 of Set 1 | saint-augustin
# Processing Record 33 of Set 1 | birao
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | mataura
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | sola
# Processing Record 39 of Set 1 | malwan
# City not found. Skipping...
# Processing Record 40 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 1 | mnogovershinnyy
# Processing Record 42 of Set 1 | stokmarknes
# Processing Record 43 of Set 1 | bubaque
# Processing Record 44 of Set 1 | barrow
# Processing Record 45 of Set 1 | picui
# Processing Record 46 of Set 1 | la ronge
# Processing Record 47 of Set 1 | upernavik
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 1 | sterling
# Processing Record 1 of Set 2 | puerto el triunfo
# Processing Record 2 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | mengcheng
# Processing Record 6 of Set 2 | ancud
# Processing Record 7 of Set 2 | the valley
# Processing Record 8 of Set 2 | kailua
# Processing Record 9 of Set 2 | capaci
# Processing Record 10 of Set 2 | lhuntshi
# City not found. Skipping...
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | hilo
# Processing Record 13 of Set 2 | santa cruz
# Processing Record 14 of Set 2 | narsaq
# Processing Record 15 of Set 2 | castro
# Processing Record 16 of Set 2 | vardo
# Processing Record 17 of Set 2 | kaeo
# Processing Record 18 of Set 2 | busselton
# Processing Record 19 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 2 | beringovskiy
# Processing Record 21 of Set 2 | bandarbeyla
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | cherskiy
# Processing Record 25 of Set 2 | sioux lookout
# Processing Record 26 of Set 2 | lompoc
# Processing Record 27 of Set 2 | bahia blanca
# Processing Record 28 of Set 2 | mao
# Processing Record 29 of Set 2 | vanavara
# Processing Record 30 of Set 2 | casian
# Processing Record 31 of Set 2 | katsuura
# Processing Record 32 of Set 2 | mamallapuram
# Processing Record 33 of Set 2 | rikitea
# Processing Record 34 of Set 2 | sorong
# Processing Record 35 of Set 2 | bozeman
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | nikolskoye
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | mayumba
# Processing Record 40 of Set 2 | coquimbo
# Processing Record 41 of Set 2 | bafq
# Processing Record 42 of Set 2 | hithadhoo
# Processing Record 43 of Set 2 | flinders
# Processing Record 44 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 2 | rocky mount
# Processing Record 46 of Set 2 | amta
# Processing Record 47 of Set 2 | srednekolymsk
# Processing Record 48 of Set 2 | kieta
# Processing Record 49 of Set 2 | torbay
# Processing Record 50 of Set 2 | cap malheureux
# Processing Record 1 of Set 3 | taoudenni
# Processing Record 2 of Set 3 | umm kaddadah
# Processing Record 3 of Set 3 | fredericksburg
# Processing Record 4 of Set 3 | manzhouli
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 7 of Set 3 | iqaluit
# Processing Record 8 of Set 3 | tiarei
# Processing Record 9 of Set 3 | emerald
# Processing Record 10 of Set 3 | loandjili
# Processing Record 11 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 3 | turayf
# Processing Record 13 of Set 3 | portsmouth
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | jamestown
# Processing Record 16 of Set 3 | ishigaki
# Processing Record 17 of Set 3 | sept-iles
# Processing Record 18 of Set 3 | guerrero negro
# Processing Record 19 of Set 3 | east london
# Processing Record 20 of Set 3 | berdigestyakh
# Processing Record 21 of Set 3 | chokurdakh
# Processing Record 22 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 23 of Set 3 | tuktoyaktuk
# Processing Record 24 of Set 3 | arraial do cabo
# Processing Record 25 of Set 3 | palora
# Processing Record 26 of Set 3 | atar
# Processing Record 27 of Set 3 | victor harbor
# Processing Record 28 of Set 3 | santa rosa
# Processing Record 29 of Set 3 | champerico
# Processing Record 30 of Set 3 | nanning
# Processing Record 31 of Set 3 | haines junction
# Processing Record 32 of Set 3 | abu samrah
# Processing Record 33 of Set 3 | sumkino
# Processing Record 34 of Set 3 | naryan-mar
# Processing Record 35 of Set 3 | labuhan
# Processing Record 36 of Set 3 | kushima
# Processing Record 37 of Set 3 | banjarmasin
# Processing Record 38 of Set 3 | yulara
# Processing Record 39 of Set 3 | sechura
# Processing Record 40 of Set 3 | carauari
# Processing Record 41 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 3 | yoichi
# Processing Record 43 of Set 3 | klaksvik
# Processing Record 44 of Set 3 | bodden town
# Processing Record 45 of Set 3 | saint-pierre
# Processing Record 46 of Set 3 | nueva gerona
# Processing Record 47 of Set 3 | hamilton
# Processing Record 48 of Set 3 | tiksi
# Processing Record 49 of Set 3 | kahului
# Processing Record 50 of Set 3 | smithers
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | barra dos coqueiros
# Processing Record 3 of Set 4 | yenagoa
# Processing Record 4 of Set 4 | almeirim
# Processing Record 5 of Set 4 | svetlyy
# Processing Record 6 of Set 4 | souillac
# Processing Record 7 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 4 | miri
# Processing Record 9 of Set 4 | berlevag
# Processing Record 10 of Set 4 | hasaki
# Processing Record 11 of Set 4 | tongliao
# Processing Record 12 of Set 4 | polyarnyy
# Processing Record 13 of Set 4 | pahrump
# Processing Record 14 of Set 4 | tadine
# Processing Record 15 of Set 4 | kodiak
# Processing Record 16 of Set 4 | ivanava
# Processing Record 17 of Set 4 | livingstonia
# Processing Record 18 of Set 4 | codrington
# Processing Record 19 of Set 4 | tuatapere
# Processing Record 20 of Set 4 | salym
# Processing Record 21 of Set 4 | roald
# Processing Record 22 of Set 4 | yendi
# Processing Record 23 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 24 of Set 4 | cairns
# Processing Record 25 of Set 4 | airai
# Processing Record 26 of Set 4 | natal
# Processing Record 27 of Set 4 | rincon
# Processing Record 28 of Set 4 | mahon
# Processing Record 29 of Set 4 | matai
# Processing Record 30 of Set 4 | saint-francois
# Processing Record 31 of Set 4 | wanlaweyn
# Processing Record 32 of Set 4 | honningsvag
# Processing Record 33 of Set 4 | wahran
# City not found. Skipping...
# Processing Record 34 of Set 4 | robertsport
# Processing Record 35 of Set 4 | wajima
# Processing Record 36 of Set 4 | srivardhan
# Processing Record 37 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 4 | tual
# Processing Record 39 of Set 4 | vung tau
# Processing Record 40 of Set 4 | thompson
# Processing Record 41 of Set 4 | cabo san lucas
# Processing Record 42 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 4 | severo-kurilsk
# Processing Record 44 of Set 4 | zhaotong
# Processing Record 45 of Set 4 | novyy urengoy
# Processing Record 46 of Set 4 | lovozero
# Processing Record 47 of Set 4 | san patricio
# Processing Record 48 of Set 4 | kloulklubed
# Processing Record 49 of Set 4 | odda
# Processing Record 50 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 5 | monforte de lemos
# Processing Record 2 of Set 5 | omboue
# Processing Record 3 of Set 5 | saint george
# Processing Record 4 of Set 5 | te anau
# Processing Record 5 of Set 5 | luba
# Processing Record 6 of Set 5 | phulpur
# Processing Record 7 of Set 5 | port lincoln
# Processing Record 8 of Set 5 | bethel
# Processing Record 9 of Set 5 | korla
# Processing Record 10 of Set 5 | tagab
# Processing Record 11 of Set 5 | provideniya
# Processing Record 12 of Set 5 | lebu
# Processing Record 13 of Set 5 | ikalamavony
# Processing Record 14 of Set 5 | cockburn town
# Processing Record 15 of Set 5 | savanur
# Processing Record 16 of Set 5 | yellowknife
# Processing Record 17 of Set 5 | shenjiamen
# Processing Record 18 of Set 5 | esperance
# Processing Record 19 of Set 5 | broome
# Processing Record 20 of Set 5 | san quintin
# Processing Record 21 of Set 5 | asfi
# Processing Record 22 of Set 5 | chiniot
# Processing Record 23 of Set 5 | sitka
# Processing Record 24 of Set 5 | rio gallegos
# Processing Record 25 of Set 5 | dingle
# Processing Record 26 of Set 5 | zhangye
# Processing Record 27 of Set 5 | longyearbyen
# Processing Record 28 of Set 5 | northam
# Processing Record 29 of Set 5 | lyngseidet
# Processing Record 30 of Set 5 | sehithwa
# Processing Record 31 of Set 5 | hambantota
# Processing Record 32 of Set 5 | mount isa
# Processing Record 33 of Set 5 | la asuncion
# Processing Record 34 of Set 5 | naze
# Processing Record 35 of Set 5 | hami
# Processing Record 36 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 5 | tiznit
# Processing Record 38 of Set 5 | humberto de campos
# Processing Record 39 of Set 5 | kenai
# Processing Record 40 of Set 5 | heilbron
# Processing Record 41 of Set 5 | saint albans
# Processing Record 42 of Set 5 | puri
# Processing Record 43 of Set 5 | falun
# Processing Record 44 of Set 5 | veraval
# Processing Record 45 of Set 5 | pacific grove
# Processing Record 46 of Set 5 | granville
# Processing Record 47 of Set 5 | vila franca do campo
# Processing Record 48 of Set 5 | mar del plata
# Processing Record 49 of Set 5 | wanxian
# Processing Record 50 of Set 5 | lattes
# Processing Record 1 of Set 6 | bontang
# Processing Record 2 of Set 6 | gua musang
# Processing Record 3 of Set 6 | shunyi
# Processing Record 4 of Set 6 | diebougou
# Processing Record 5 of Set 6 | geraldton
# Processing Record 6 of Set 6 | seoul
# Processing Record 7 of Set 6 | port hardy
# Processing Record 8 of Set 6 | pine bluff
# Processing Record 9 of Set 6 | balimo
# City not found. Skipping...
# Processing Record 10 of Set 6 | rundu
# Processing Record 11 of Set 6 | samana
# Processing Record 12 of Set 6 | boa vista
# Processing Record 13 of Set 6 | abha
# Processing Record 14 of Set 6 | onda
# Processing Record 15 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 6 | xining
# Processing Record 17 of Set 6 | manadhoo
# Processing Record 18 of Set 6 | mount gambier
# Processing Record 19 of Set 6 | takestan
# Processing Record 20 of Set 6 | gorom-gorom
# Processing Record 21 of Set 6 | matadi
# Processing Record 22 of Set 6 | powell river
# Processing Record 23 of Set 6 | marystown
# Processing Record 24 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 6 | borovskoy
# Processing Record 26 of Set 6 | camana
# Processing Record 27 of Set 6 | bambous virieux
# Processing Record 28 of Set 6 | aksarka
# Processing Record 29 of Set 6 | muisne
# Processing Record 30 of Set 6 | brawley
# Processing Record 31 of Set 6 | praia da vitoria
# Processing Record 32 of Set 6 | pingyin
# Processing Record 33 of Set 6 | nynashamn
# Processing Record 34 of Set 6 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 6 | chuncheng
# Processing Record 36 of Set 6 | arlit
# Processing Record 37 of Set 6 | ayer itam
# City not found. Skipping...
# Processing Record 38 of Set 6 | mandera
# Processing Record 39 of Set 6 | tumaco
# Processing Record 40 of Set 6 | melchor de mencos
# Processing Record 41 of Set 6 | meadow lake
# Processing Record 42 of Set 6 | dukat
# Processing Record 43 of Set 6 | namibe
# Processing Record 44 of Set 6 | bilina
# Processing Record 45 of Set 6 | okhotsk
# Processing Record 46 of Set 6 | verkhnevilyuysk
# Processing Record 47 of Set 6 | pafos
# Processing Record 48 of Set 6 | hobart
# Processing Record 49 of Set 6 | sabang
# Processing Record 50 of Set 6 | roma
# Processing Record 1 of Set 7 | nemuro
# Processing Record 2 of Set 7 | mersing
# Processing Record 3 of Set 7 | dillon
# Processing Record 4 of Set 7 | chyhyryn
# Processing Record 5 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 7 | port moresby
# Processing Record 7 of Set 7 | bengkulu
# Processing Record 8 of Set 7 | lagoa
# Processing Record 9 of Set 7 | praia
# Processing Record 10 of Set 7 | la ciotat
# Processing Record 11 of Set 7 | lavrentiya
# Processing Record 12 of Set 7 | valeggio sul mincio
# Processing Record 13 of Set 7 | kawalu
# Processing Record 14 of Set 7 | mangrol
# Processing Record 15 of Set 7 | saldanha
# Processing Record 16 of Set 7 | harper
# Processing Record 17 of Set 7 | vangaindrano
# Processing Record 18 of Set 7 | norman wells
# Processing Record 19 of Set 7 | tinos
# Processing Record 20 of Set 7 | huinan
# Processing Record 21 of Set 7 | saskylakh
# Processing Record 22 of Set 7 | ayr
# Processing Record 23 of Set 7 | soyo
# Processing Record 24 of Set 7 | coihaique
# Processing Record 25 of Set 7 | ilulissat
# Processing Record 26 of Set 7 | bredasdorp
# Processing Record 27 of Set 7 | la maddalena
# Processing Record 28 of Set 7 | satitoa
# City not found. Skipping...
# Processing Record 29 of Set 7 | nanortalik
# Processing Record 30 of Set 7 | plettenberg bay
# Processing Record 31 of Set 7 | kavaratti
# Processing Record 32 of Set 7 | asau
# Processing Record 33 of Set 7 | tura
# Processing Record 34 of Set 7 | matara
# Processing Record 35 of Set 7 | novonikolayevskiy
# Processing Record 36 of Set 7 | teya
# Processing Record 37 of Set 7 | wilmington
# Processing Record 38 of Set 7 | sao joao da barra
# Processing Record 39 of Set 7 | loubomo
# Processing Record 40 of Set 7 | maceio
# Processing Record 41 of Set 7 | tommot
# Processing Record 42 of Set 7 | ulladulla
# Processing Record 43 of Set 7 | andevoranto
# City not found. Skipping...
# Processing Record 44 of Set 7 | padang
# Processing Record 45 of Set 7 | tilichiki
# Processing Record 46 of Set 7 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 47 of Set 7 | higuey
# City not found. Skipping...
# Processing Record 48 of Set 7 | paucartambo
# City not found. Skipping...
# Processing Record 49 of Set 7 | dangtu
# Processing Record 50 of Set 7 | davidson
# Processing Record 1 of Set 8 | dom pedrito
# Processing Record 2 of Set 8 | coos bay
# Processing Record 3 of Set 8 | morondava
# Processing Record 4 of Set 8 | huilong
# Processing Record 5 of Set 8 | beisfjord
# Processing Record 6 of Set 8 | varenikovskaya
# Processing Record 7 of Set 8 | alpena
# Processing Record 8 of Set 8 | praya
# Processing Record 9 of Set 8 | nouadhibou
# Processing Record 10 of Set 8 | wajir
# Processing Record 11 of Set 8 | los llanos de aridane
# Processing Record 12 of Set 8 | tambopata
# Processing Record 13 of Set 8 | college
# Processing Record 14 of Set 8 | ambodifototra
# City not found. Skipping...
# Processing Record 15 of Set 8 | grootfontein
# Processing Record 16 of Set 8 | ribeira grande
# Processing Record 17 of Set 8 | eureka
# Processing Record 18 of Set 8 | marawi
# Processing Record 19 of Set 8 | bathsheba
# Processing Record 20 of Set 8 | veere
# Processing Record 21 of Set 8 | jerantut
# Processing Record 22 of Set 8 | manzanillo
# Processing Record 23 of Set 8 | mortka
# Processing Record 24 of Set 8 | atikokan
# Processing Record 25 of Set 8 | iskateley
# Processing Record 26 of Set 8 | nabisar
# Processing Record 27 of Set 8 | el guapinol
# Processing Record 28 of Set 8 | pontian kecil
# Processing Record 29 of Set 8 | vredendal
# Processing Record 30 of Set 8 | raudeberg
# Processing Record 31 of Set 8 | yerbogachen
# Processing Record 32 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 8 | inhambane
# Processing Record 34 of Set 8 | coihueco
# Processing Record 35 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 8 | shakawe
# Processing Record 37 of Set 8 | leshukonskoye
# Processing Record 38 of Set 8 | nizwa
# Processing Record 39 of Set 8 | virginia beach
# Processing Record 40 of Set 8 | sakakah
# Processing Record 41 of Set 8 | pisco
# Processing Record 42 of Set 8 | karasjok
# Processing Record 43 of Set 8 | namatanai
# Processing Record 44 of Set 8 | bosconia
# Processing Record 45 of Set 8 | jaen
# Processing Record 46 of Set 8 | mahibadhoo
# Processing Record 47 of Set 8 | ambon
# Processing Record 48 of Set 8 | puro
# Processing Record 49 of Set 8 | faanui
# Processing Record 50 of Set 8 | jizan
# Processing Record 1 of Set 9 | westport
# Processing Record 2 of Set 9 | poykovskiy
# Processing Record 3 of Set 9 | flin flon
# Processing Record 4 of Set 9 | grande prairie
# Processing Record 5 of Set 9 | salinopolis
# Processing Record 6 of Set 9 | clyde river
# Processing Record 7 of Set 9 | grindavik
# Processing Record 8 of Set 9 | tabiauea
# City not found. Skipping...
# Processing Record 9 of Set 9 | itarema
# Processing Record 10 of Set 9 | muzhi
# Processing Record 11 of Set 9 | luwuk
# Processing Record 12 of Set 9 | tres lagoas
# Processing Record 13 of Set 9 | limbang
# Processing Record 14 of Set 9 | mayor pablo lagerenza
# Processing Record 15 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 16 of Set 9 | dubbo
# Processing Record 17 of Set 9 | chuy
# Processing Record 18 of Set 9 | khairagarh
# Processing Record 19 of Set 9 | pauini
# Processing Record 20 of Set 9 | palu
# Processing Record 21 of Set 9 | potma
# City not found. Skipping...
# Processing Record 22 of Set 9 | vao
# Processing Record 23 of Set 9 | iranshahr
# Processing Record 24 of Set 9 | coronado
# Processing Record 25 of Set 9 | solnechnyy
# Processing Record 26 of Set 9 | nevesinje
# Processing Record 27 of Set 9 | neiafu
# Processing Record 28 of Set 9 | fort smith
# Processing Record 29 of Set 9 | dunedin
# Processing Record 30 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 31 of Set 9 | auki
# Processing Record 32 of Set 9 | goderich
# Processing Record 33 of Set 9 | qujing
# Processing Record 34 of Set 9 | shingu
# Processing Record 35 of Set 9 | callaguip
# Processing Record 36 of Set 9 | cuamba
# Processing Record 37 of Set 9 | maniitsoq
# Processing Record 38 of Set 9 | nantucket
# Processing Record 39 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 9 | nevsehir
# Processing Record 41 of Set 9 | compostela
# Processing Record 42 of Set 9 | plesetsk
# Processing Record 43 of Set 9 | punta de piedra
# Processing Record 44 of Set 9 | coxim
# Processing Record 45 of Set 9 | aberdeen
# Processing Record 46 of Set 9 | marsa matruh
# Processing Record 47 of Set 9 | patacamaya
# Processing Record 48 of Set 9 | gangotri
# City not found. Skipping...
# Processing Record 49 of Set 9 | porbandar
# Processing Record 50 of Set 9 | hobyo
# Processing Record 1 of Set 10 | auburn
# Processing Record 2 of Set 10 | rawson
# Processing Record 3 of Set 10 | lagos
# Processing Record 4 of Set 10 | narasannapeta
# Processing Record 5 of Set 10 | llandrindod wells
# Processing Record 6 of Set 10 | nome
# Processing Record 7 of Set 10 | dubrovka
# Processing Record 8 of Set 10 | san rafael
# Processing Record 9 of Set 10 | wencheng
# Processing Record 10 of Set 10 | ostrovnoy
# Processing Record 11 of Set 10 | sao felix do xingu
# Processing Record 12 of Set 10 | wanning
# Processing Record 13 of Set 10 | mareeba
# Processing Record 14 of Set 10 | balabac
# Processing Record 15 of Set 10 | dalianwan
# Processing Record 16 of Set 10 | krumbach
# Processing Record 17 of Set 10 | kemijarvi
# Processing Record 18 of Set 10 | port blair
# Processing Record 19 of Set 10 | byron bay
# Processing Record 20 of Set 10 | olafsvik
# Processing Record 21 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 22 of Set 10 | temeni
# Processing Record 23 of Set 10 | biak
# Processing Record 24 of Set 10 | komsomolets
# Processing Record 25 of Set 10 | camacha
# Processing Record 26 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 27 of Set 10 | eshowe
# Processing Record 28 of Set 10 | georgetown
# Processing Record 29 of Set 10 | luderitz
# Processing Record 30 of Set 10 | antofagasta
# Processing Record 31 of Set 10 | moose factory
# Processing Record 32 of Set 10 | zyryanka
# Processing Record 33 of Set 10 | novosergiyevka
# Processing Record 34 of Set 10 | qaqortoq
# Processing Record 35 of Set 10 | gohpur
# Processing Record 36 of Set 10 | diamantino
# Processing Record 37 of Set 10 | boguchany
# Processing Record 38 of Set 10 | yumen
# Processing Record 39 of Set 10 | curico
# Processing Record 40 of Set 10 | hendijan
# City not found. Skipping...
# Processing Record 41 of Set 10 | fort madison
# Processing Record 42 of Set 10 | komsomolskiy
# Processing Record 43 of Set 10 | tombouctou
# Processing Record 44 of Set 10 | fairbanks
# Processing Record 45 of Set 10 | villa san giovanni
# Processing Record 46 of Set 10 | channel-port aux basques
# Processing Record 47 of Set 10 | makarov
# Processing Record 48 of Set 10 | lisala
# Processing Record 49 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 50 of Set 10 | espanola
# Processing Record 1 of Set 11 | gavle
# Processing Record 2 of Set 11 | yuanping
# Processing Record 3 of Set 11 | seven hills
# Processing Record 4 of Set 11 | merzig
# Processing Record 5 of Set 11 | batemans bay
# Processing Record 6 of Set 11 | viransehir
# Processing Record 7 of Set 11 | vila velha
# Processing Record 8 of Set 11 | viedma
# Processing Record 9 of Set 11 | galle
# Processing Record 10 of Set 11 | sosnovo-ozerskoye
# Processing Record 11 of Set 11 | vaiano
# Processing Record 12 of Set 11 | high level
# Processing Record 13 of Set 11 | kabalo
# Processing Record 14 of Set 11 | seryshevo
# Processing Record 15 of Set 11 | vasto
# Processing Record 16 of Set 11 | nishihara
# Processing Record 17 of Set 11 | chuguyevka
# Processing Record 18 of Set 11 | esmeraldas
# Processing Record 19 of Set 11 | saltillo
# Processing Record 20 of Set 11 | malaya purga
# Processing Record 21 of Set 11 | voznesenye
# Processing Record 22 of Set 11 | ocara
# Processing Record 23 of Set 11 | aljezur
# Processing Record 24 of Set 11 | poum
# Processing Record 25 of Set 11 | elat
# Processing Record 26 of Set 11 | monte patria
# Processing Record 27 of Set 11 | baoqing
# Processing Record 28 of Set 11 | qasigiannguit
# Processing Record 29 of Set 11 | kouango
# Processing Record 30 of Set 11 | kiunga
# Processing Record 31 of Set 11 | killybegs
# Processing Record 32 of Set 11 | kafanchan
# Processing Record 33 of Set 11 | bhatkal
# Processing Record 34 of Set 11 | amapa
# Processing Record 35 of Set 11 | sakaiminato
# Processing Record 36 of Set 11 | okha
# Processing Record 37 of Set 11 | sandpoint
# Processing Record 38 of Set 11 | play cu
# City not found. Skipping...
# Processing Record 39 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 11 | ixtapa
# Processing Record 41 of Set 11 | karaton
# Processing Record 42 of Set 11 | palana
# Processing Record 43 of Set 11 | aklavik
# Processing Record 44 of Set 11 | broken hill
# Processing Record 45 of Set 11 | gweru
# Processing Record 46 of Set 11 | bilara
# Processing Record 47 of Set 11 | athabasca
# Processing Record 48 of Set 11 | tshikapa
# Processing Record 49 of Set 11 | khorixas
# Processing Record 50 of Set 11 | kizema
# Processing Record 1 of Set 12 | kenora
# Processing Record 2 of Set 12 | bilibino
# Processing Record 3 of Set 12 | miandrivazo
# Processing Record 4 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 12 | oranjemund
# Processing Record 6 of Set 12 | sobolevo
# Processing Record 7 of Set 12 | talnakh
# Processing Record 8 of Set 12 | tromso
# Processing Record 9 of Set 12 | hornepayne
# Processing Record 10 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 12 | saint stephen
# Processing Record 12 of Set 12 | mankono
# Processing Record 13 of Set 12 | hemnesberget
# Processing Record 14 of Set 12 | sandeid
# Processing Record 15 of Set 12 | singaraja
# Processing Record 16 of Set 12 | constitucion
# Processing Record 17 of Set 12 | hofn
# Processing Record 18 of Set 12 | lodja
# Processing Record 19 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 12 | ambilobe
# Processing Record 21 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 22 of Set 12 | yaypan
# Processing Record 23 of Set 12 | sangar
# Processing Record 24 of Set 12 | falkoping
# City not found. Skipping...
# Processing Record 25 of Set 12 | lucea
# Processing Record 26 of Set 12 | ouesso
# Processing Record 27 of Set 12 | linxia
# Processing Record 28 of Set 12 | pontes e lacerda
# Processing Record 29 of Set 12 | lethem
# Processing Record 30 of Set 12 | sinnamary
# Processing Record 31 of Set 12 | konevo
# Processing Record 32 of Set 12 | gunjur
# Processing Record 33 of Set 12 | denpasar
# Processing Record 34 of Set 12 | erzin
# Processing Record 35 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 12 | kerrville
# Processing Record 37 of Set 12 | vidim
# Processing Record 38 of Set 12 | antalya
# Processing Record 39 of Set 12 | honiara
# Processing Record 40 of Set 12 | selizharovo
# Processing Record 41 of Set 12 | bilma
# Processing Record 42 of Set 12 | ayan
# Processing Record 43 of Set 12 | ambo
# Processing Record 44 of Set 12 | makokou
# Processing Record 45 of Set 12 | dolores
# Processing Record 46 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 47 of Set 12 | lixourion
# Processing Record 48 of Set 12 | marzuq
# Processing Record 49 of Set 12 | qingquan
# Processing Record 50 of Set 12 | ornskoldsvik
# Processing Record 1 of Set 13 | ust-kulom
# Processing Record 2 of Set 13 | ust-maya
# Processing Record 3 of Set 13 | alekseyevskoye
# Processing Record 4 of Set 13 | katghora
# Processing Record 5 of Set 13 | toora-khem
# Processing Record 6 of Set 13 | igarka
# Processing Record 7 of Set 13 | husavik
# Processing Record 8 of Set 13 | palmer
# Processing Record 9 of Set 13 | ambikapur
# Processing Record 10 of Set 13 | minab
# Processing Record 11 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 12 of Set 13 | matagami
# Processing Record 13 of Set 13 | cayenne
# Processing Record 14 of Set 13 | takaka
# Processing Record 15 of Set 13 | nuuk
# Processing Record 16 of Set 13 | marrakesh
# Processing Record 17 of Set 13 | hyeres
# Processing Record 18 of Set 13 | kokstad
# Processing Record 19 of Set 13 | aitape
# Processing Record 20 of Set 13 | olbia
# Processing Record 21 of Set 13 | comodoro rivadavia
# Processing Record 22 of Set 13 | buqayq
# City not found. Skipping...
# Processing Record 23 of Set 13 | catuday
# Processing Record 24 of Set 13 | bogyiszlo
# Processing Record 25 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 13 | zhigalovo
# Processing Record 27 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 28 of Set 13 | camocim
# Processing Record 29 of Set 13 | bonavista
# Processing Record 30 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 31 of Set 13 | brooks
# Processing Record 32 of Set 13 | buala
# Processing Record 33 of Set 13 | kulhudhuffushi
# Processing Record 34 of Set 13 | wichita falls
# Processing Record 35 of Set 13 | hualmay
# Processing Record 36 of Set 13 | san fernando
# Processing Record 37 of Set 13 | zaterechnyy
# Processing Record 38 of Set 13 | lchashen
# Processing Record 39 of Set 13 | mweka
# Processing Record 40 of Set 13 | cubuk
# Processing Record 41 of Set 13 | pale
# Processing Record 42 of Set 13 | derzhavinsk
# Processing Record 43 of Set 13 | chimoio
# Processing Record 44 of Set 13 | the pas
# Processing Record 45 of Set 13 | lasa
# Processing Record 46 of Set 13 | laguna
# Processing Record 47 of Set 13 | zhezkazgan
# Processing Record 48 of Set 13 | bambanglipuro
# Processing Record 49 of Set 13 | henderson
# Processing Record 50 of Set 13 | noumea
# Processing Record 1 of Set 14 | summerville
# Processing Record 2 of Set 14 | ahtopol
# Processing Record 3 of Set 14 | hovd
# Processing Record 4 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 14 | caarapo
# Processing Record 6 of Set 14 | chapais
# Processing Record 7 of Set 14 | lobva
# Processing Record 8 of Set 14 | goma
# Processing Record 9 of Set 14 | petukhovo
# Processing Record 10 of Set 14 | port keats
# Processing Record 11 of Set 14 | hokitika
# Processing Record 12 of Set 14 | livadiya
# Processing Record 13 of Set 14 | da nang
# Processing Record 14 of Set 14 | paracatu
# Processing Record 15 of Set 14 | takoradi
# Processing Record 16 of Set 14 | porto novo
# Processing Record 17 of Set 14 | binga
# Processing Record 18 of Set 14 | mpanda
# Processing Record 19 of Set 14 | soubre
# Processing Record 20 of Set 14 | mopipi
# Processing Record 21 of Set 14 | ternate
# Processing Record 22 of Set 14 | baykit
# Processing Record 23 of Set 14 | zheleznodorozhnyy
# Processing Record 24 of Set 14 | saint-joseph
# Processing Record 25 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 14 | houston
# Processing Record 27 of Set 14 | bereda
# Processing Record 28 of Set 14 | essenbach
# Processing Record 29 of Set 14 | velikooktyabrskiy
# Processing Record 30 of Set 14 | imbituba
# Processing Record 31 of Set 14 | caravelas
# Processing Record 32 of Set 14 | rorvik
# Processing Record 33 of Set 14 | srandakan
# Processing Record 34 of Set 14 | staraya mayna
# Processing Record 35 of Set 14 | nicolas bravo
# Processing Record 36 of Set 14 | lata
# Processing Record 37 of Set 14 | quirinopolis
# Processing Record 38 of Set 14 | wattegama
# Processing Record 39 of Set 14 | nhulunbuy
# Processing Record 40 of Set 14 | mujiayingzi
# Processing Record 41 of Set 14 | olinda
# Processing Record 42 of Set 14 | yekaterinovka
# Processing Record 43 of Set 14 | minot
# Processing Record 44 of Set 14 | gazanjyk
# Processing Record 45 of Set 14 | atherton
# Processing Record 46 of Set 14 | vostok
# Processing Record 47 of Set 14 | bani
# Processing Record 48 of Set 14 | boende
# Processing Record 49 of Set 14 | port hedland
# Processing Record 50 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 1 of Set 15 | sudak
# Processing Record 2 of Set 15 | siloam springs
# Processing Record 3 of Set 15 | kondinskoye
# Processing Record 4 of Set 15 | joao pinheiro
# Processing Record 5 of Set 15 | corn island
# Processing Record 6 of Set 15 | tashla
# Processing Record 7 of Set 15 | mazagao
# Processing Record 8 of Set 15 | uvalde
# Processing Record 9 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 15 | oktyabrskoye
# Processing Record 11 of Set 15 | ushirombo
# Processing Record 12 of Set 15 | opuwo
# Processing Record 13 of Set 15 | taitung
# Processing Record 14 of Set 15 | freeport
# Processing Record 15 of Set 15 | vydrino
# Processing Record 16 of Set 15 | vestmannaeyjar
# Processing Record 17 of Set 15 | harer
# Processing Record 18 of Set 15 | faya
# Processing Record 19 of Set 15 | bafia
# Processing Record 20 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 15 | udachnyy
# Processing Record 22 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 23 of Set 15 | akyab
# Processing Record 24 of Set 15 | aykhal
# Processing Record 25 of Set 15 | pemangkat
# Processing Record 26 of Set 15 | kaseda
# Processing Record 27 of Set 15 | wilkie
# Processing Record 28 of Set 15 | angoche
# Processing Record 29 of Set 15 | paita
# Processing Record 30 of Set 15 | prabumulih
# Processing Record 31 of Set 15 | merauke
# Processing Record 32 of Set 15 | palauig
# Processing Record 33 of Set 15 | port shepstone
# Processing Record 34 of Set 15 | jodar
# Processing Record 35 of Set 15 | rantepao
# Processing Record 36 of Set 15 | raton
# Processing Record 37 of Set 15 | west wendover
# Processing Record 38 of Set 15 | newnan
# Processing Record 39 of Set 15 | harsany
# Processing Record 40 of Set 15 | nova ushytsya
# Processing Record 41 of Set 15 | hue
# Processing Record 42 of Set 15 | san jose
# Processing Record 43 of Set 15 | dakoro
# Processing Record 44 of Set 15 | ust-ilimsk
# Processing Record 45 of Set 15 | sudzha
# Processing Record 46 of Set 15 | touros
# Processing Record 47 of Set 15 | sulechow
# Processing Record 48 of Set 15 | toyooka
# Processing Record 49 of Set 15 | bonthe
# Processing Record 50 of Set 15 | maldonado
# Processing Record 1 of Set 16 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 16 | ciledug
# City not found. Skipping...
# Processing Record 3 of Set 16 | ugoofaaru
# -------------------------------
# Wheather Data from API recorded
# -------------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 688

# %%
# Step 7: Add the data to a new DataFrame.
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Salalah      OM  17.0151   54.0924     21.20        70           2
# 1        Staritsa      RU  56.5075   34.9354     -3.58        88          90
# 2           Pevek      RU  69.7008  170.3133    -30.58        98         100
# 3           Colon      PA   9.3592  -79.9014     34.45        64          14
# 4        Tasiilaq      GL  65.6145  -37.6368    -14.74        66         100
# 5           Rocha      UY -34.4833  -54.3333     18.90        94         100
# 6           Bluff      NZ -46.6000  168.3333     11.00        70         100
# 7          Dikson      RU  73.5069   80.5464    -19.40        78         100
# 8           Kapaa      US  22.0752 -159.3190     25.18        74          40
# 9  Saint-Philippe      RE -21.3585   55.7679     25.75        84          28
#
#    Wind Speed Current Description
# 0        0.68           clear sky
# 1        5.76     overcast clouds
# 2        4.22     overcast clouds
# 3        5.57          few clouds
# 4        1.81     overcast clouds
# 5        8.10     overcast clouds
# 6        5.79     overcast clouds
# 7       12.04     overcast clouds
# 8        5.14    scattered clouds
# 9        4.97    scattered clouds

# %%
# Step 8: Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder
city_weather_db_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(city_weather_db_file, index_label="CityID")
